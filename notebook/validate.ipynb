# %%
import numpy as np 
from scipy import stats
rng = np.random.default_rng()
sample1 = stats.uniform.rvs(size=100,random_state=rng)
sample2 = stats.norm.rvs(size=100,random_state=rng)
repsonse = stats.ks_2samp(sample1,sample2)

# %%
repsonse
# Out:
# KstestResult(statistic=0.58, pvalue=6.689905084769254e-16)

# %%
sample1
# Out:
# array([0.72160653, 0.45296206, 0.35331708, 0.6221998 , 0.26639189,
#        0.38014013, 0.36731491, 0.96114786, 0.76971424, 0.15240392,
#        0.21481204, 0.69311337, 0.58942402, 0.22492184, 0.50472135,
#        0.84481413, 0.08868499, 0.22781877, 0.54331743, 0.40390786,
#        0.41914094, 0.01716433, 0.25685919, 0.04987836, 0.82455144,
#        0.57669498, 0.63010794, 0.03415802, 0.37393916, 0.75249488,
#        0.94084828, 0.08458931, 0.37153899, 0.07484779, 0.04956076,
#        0.54103394, 0.41696709, 0.91544392, 0.30852493, 0.71660843,
#        0.81014076, 0.56147893, 0.97029704, 0.39510877, 0.3055368 ,
#        0.64338942, 0.84289262, 0.73239749, 0.94471987, 0.19689349,
#        0.15775623, 0.90337845, 0.96620747, 0.93732395, 0.72086019,
#        0.05029509, 0.60139576, 0.54087415, 0.31694896, 0.22721572,
#        0.63572594, 0.85355252, 0.46024652, 0.39336545, 0.91245238,
#        0.18880987, 0.92185081, 0.01324391, 0.35323413, 0.12172747,
#        0.00329722, 0.93169371, 0.79279492, 0.00741888, 0.09001002,
#        0.60547428, 0.17206015, 0.72388507, 0.49759689, 0.60881386,
#        0.67747857, 0.70047907, 0.20002977, 0.31579777, 0.27045854,
#        0.06124663, 0.83584331, 0.56276219, 0.5113311 , 0.50574023,
#        0.66919106, 0.50580395, 0.7421153 , 0.00332658, 0.04454792,
#        0.49937013, 0.76966756, 0.49474269, 0.55768119, 0.71365108])

# %%
sample2
# Out:
# array([-5.25948784e-01, -2.67715135e-02,  7.24363683e-01, -1.64832255e-01,
#         7.77120940e-01, -1.73789761e+00,  4.02725553e-01, -2.71018388e-01,
#        -1.45193035e-01, -2.23054572e-01,  2.25051256e+00, -7.68307081e-01,
#         2.45824517e-02,  6.69827588e-01, -1.99455769e+00, -3.15587447e-01,
#        -1.01600817e+00, -1.55269356e-01,  1.05726517e+00, -1.45828916e+00,
#         1.56418025e+00, -8.38229896e-02, -2.20243736e-01, -5.79795744e-01,
#        -7.00685217e-01, -9.44613754e-01,  4.90318664e-01, -5.08938401e-01,
#        -3.98167503e-01,  3.20793798e-01,  3.39548869e-01,  2.17563050e+00,
#        -4.19467973e-01, -3.34209093e-02,  1.24326576e+00, -7.72144208e-02,
#         1.22912326e+00,  1.28859429e+00,  9.22598164e-03,  3.38973635e-01,
#         5.53937523e-01, -5.92027732e-01, -2.71925784e-01,  2.32682717e-01,
#        -9.26510394e-01,  6.93598759e-01, -2.50924268e+00, -5.51280887e-01,
#         1.82143194e-01,  1.83002742e-01, -1.08813017e+00, -5.40201865e-01,
#         1.04229338e+00, -2.90486112e-01,  1.13135294e+00, -9.67600090e-01,
#        -1.14528850e+00, -1.58554776e+00, -7.67316103e-01, -5.46641689e-01,
#         1.22791375e-01, -5.37721704e-01, -3.81199856e-01,  1.24495662e+00,
#        -8.41053405e-01, -4.59086265e-01, -1.72178656e+00,  3.91197485e-01,
#         1.20859604e+00, -1.16509310e+00, -1.21622647e-01,  7.51799698e-01,
#         3.40926047e-01, -1.16961604e-01,  9.84912259e-01,  1.11686285e+00,
#        -2.18977038e+00, -1.52934403e-02,  1.20509231e+00,  9.63532853e-01,
#        -1.16252711e+00, -3.37905593e-01, -2.39731841e-01,  2.29933897e+00,
#        -9.39608276e-04,  2.05703119e-01, -5.75460616e-01,  3.22226233e-01,
#        -4.88605530e-01, -1.68078008e+00, -2.02027486e+00,  4.13177132e-01,
#         2.38447211e-01,  3.49660285e-01, -3.95328001e-01, -1.55959211e+00,
#        -5.52406806e-01, -6.58005381e-01,  2.11337421e+00,  1.84770200e-01])

# %%
repsonse.pvalue
# Out:
# 6.689905084769254e-16

# %%
#Anamoly in dataset
1.High Null Value
2. Missing Value
3. Outlier
4. Categorical

# %%
import pandas as pd

# %%
df = pd.read_csv("/config/workspace/artifact/12052022__104134/data_ingestion/dataset/train.csv")

# %%
(df.isnull().sum()/df.shape[0]).values
# Out:
# 171

# %%
drop_column_names=[]
for column_name,missing_percentage in zip((df.isnull().sum()/df.shape[0]).index, (df.isnull().sum()/df.shape[0]).values):
    print(column_name,missing_percentage*100)
    if missing_percentage >0.3:
        drop_column_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.11226252158895
# ac_000 5.899827288428325
# ad_000 25.385146804835923
# ae_000 4.414507772020725
# af_000 4.414507772020725
# ag_000 1.0431778929188256
# ag_001 1.0431778929188256
# ag_002 1.0431778929188256
# ag_003 1.0431778929188256
# ag_004 1.0431778929188256
# ag_005 1.0431778929188256
# ag_006 1.0431778929188256
# ag_007 1.0431778929188256
# ag_008 1.0431778929188256
# ag_009 1.0431778929188256
# ah_000 1.0189982728842832
# ai_000 1.005181347150259
# aj_000 1.005181347150259
# ak_000 7.661485319516408
# al_000 1.0224525043177894
# am_0 1.005181347150259
# an_000 1.0224525043177894
# ao_000 0.932642487046632
# ap_000 1.0224525043177894
# aq_000 0.932642487046632
# ar_000 4.784110535405873
# as_000 1.005181347150259
# at_000 1.005181347150259
# au_000 1.005181347150259
# av_000 4.414507772020725
# ax_000 4.417962003454232
# ay_000 1.0431778929188256
# ay_001 1.0431778929188256
# ay_002 1.0431778929188256
# ay_003 1.0431778929188256
# ay_004 1.0431778929188256
# ay_005 1.0431778929188256
# ay_006 1.0431778929188256
# ay_007 1.0431778929188256
# ay_008 1.0431778929188256
# ay_009 1.0431778929188256
# az_000 1.0431778929188256
# az_001 1.0431778929188256
# az_002 1.0431778929188256
# az_003 1.0431778929188256
# az_004 1.0431778929188256
# az_005 1.0431778929188256
# az_006 1.0431778929188256
# az_007 1.0431778929188256
# az_008 1.0431778929188256
# az_009 1.0431778929188256
# ba_000 1.063903281519862
# ba_001 1.063903281519862
# ba_002 1.063903281519862
# ba_003 1.063903281519862
# ba_004 1.063903281519862
# ba_005 1.063903281519862
# ba_006 1.063903281519862
# ba_007 1.063903281519862
# ba_008 1.063903281519862
# ba_009 1.063903281519862
# bb_000 1.0189982728842832
# bc_000 4.794473229706391
# bd_000 4.7979274611398965
# be_000 4.424870466321243
# bf_000 4.411053540587219
# bg_000 1.0224525043177894
# bh_000 1.0224525043177894
# bi_000 0.932642487046632
# bj_000 0.932642487046632
# bk_000 38.200345423143354
# bl_000 45.160621761658035
# bm_000 65.5993091537133
# bn_000 72.81174438687393
# bo_000 76.60103626943005
# bp_000 78.83246977547496
# bq_000 80.52158894645942
# br_000 81.46459412780656
# bs_000 1.1053540587219344
# bt_000 0.22452504317789293
# bu_000 1.07426597582038
# bv_000 1.07426597582038
# bx_000 5.229706390328151
# by_000 0.7495682210708118
# bz_000 4.784110535405873
# ca_000 7.557858376511225
# cb_000 1.1053540587219344
# cc_000 5.2262521588946464
# cd_000 1.0949913644214162
# ce_000 4.414507772020725
# cf_000 25.385146804835923
# cg_000 25.385146804835923
# ch_000 25.385146804835923
# ci_000 0.5561312607944733
# cj_000 0.5561312607944733
# ck_000 0.5561312607944733
# cl_000 15.903281519861832
# cm_000 16.556131260794473
# cn_000 1.060449050086356
# cn_001 1.060449050086356
# cn_002 1.060449050086356
# cn_003 1.060449050086356
# cn_004 1.060449050086356
# cn_005 1.060449050086356
# cn_006 1.060449050086356
# cn_007 1.060449050086356
# cn_008 1.060449050086356
# cn_009 1.060449050086356
# co_000 25.385146804835923
# cp_000 4.787564766839378
# cq_000 1.07426597582038
# cr_000 77.11226252158895
# cs_000 1.0397236614853196
# cs_001 1.0397236614853196
# cs_002 1.0397236614853196
# cs_003 1.0397236614853196
# cs_004 1.0397236614853196
# cs_005 1.0397236614853196
# cs_006 1.0397236614853196
# cs_007 1.0397236614853196
# cs_008 1.0397236614853196
# cs_009 1.0397236614853196
# ct_000 23.50949913644214
# cu_000 23.50949913644214
# cv_000 23.50949913644214
# cx_000 23.50949913644214
# cy_000 23.50949913644214
# cz_000 23.50949913644214
# da_000 23.50949913644214
# db_000 23.50949913644214
# dc_000 23.50949913644214
# dd_000 4.4214162348877375
# de_000 4.787564766839378
# df_000 7.018998272884283
# dg_000 7.018998272884283
# dh_000 7.018998272884283
# di_000 7.0120898100172715
# dj_000 7.015544041450777
# dk_000 7.015544041450777
# dl_000 7.018998272884283
# dm_000 7.022452504317789
# dn_000 1.07426597582038
# do_000 4.791018998272884
# dp_000 4.794473229706391
# dq_000 4.794473229706391
# dr_000 4.791018998272884
# ds_000 4.794473229706391
# dt_000 4.794473229706391
# du_000 4.791018998272884
# dv_000 4.791018998272884
# dx_000 4.784110535405873
# dy_000 4.787564766839378
# dz_000 4.784110535405873
# ea_000 4.784110535405873
# eb_000 7.015544041450777
# ec_00 17.088082901554404
# ed_000 15.903281519861832
# ee_000 1.0431778929188256
# ee_001 1.0431778929188256
# ee_002 1.0431778929188256
# ee_003 1.0431778929188256
# ee_004 1.0431778929188256
# ee_005 1.0431778929188256
# ee_006 1.0431778929188256
# ee_007 1.0431778929188256
# ee_008 1.0431778929188256
# ee_009 1.0431778929188256
# ef_000 4.787564766839378
# eg_000 4.784110535405873

# %%
drop_column_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']

# %%
from glob import glob

# %%
glob("/config/workspace/saved_models/1/*.pkl")
# Out:
# []

# %%
import os
os.path.basename('saved_model/1')
# Out:
# '1'
